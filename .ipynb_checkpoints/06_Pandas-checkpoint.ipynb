# %% [markdown]
# # Pandas
#
# The `numpy` module is excellent for numerical computations, but to handle missing data or arrays with mixed types takes more work. The `pandas` module is currently the most widely used tool for data manipulation, providing high-performance, easy-to-use data structures and advanced data analysis tools.
#
# In particular `pandas` features:
#
# * A fast and efficient "DataFrame" object for data manipulation with integrated indexing;
# * Tools for reading and writing data between in-memory data structures and different formats (CSV, Excel, SQL, HDF5);
# * Intelligent data alignment and integrated handling of missing data;
# * Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
# * Aggregating or transforming data with a powerful "group-by" engine;
# * High performance merging and joining of data sets;
# * Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
# * Time series-functionalities;
# * Highly optimized for performance, with critical code paths written in Cython or C.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series
#
# Series are completely equivalent to 1D array but with axis labels and the possibility to store heterogeneous elements. Of paramount importance are the time-series, used to define time evolutions of a phenomenon.

# %%
from string import ascii_lowercase as letters

# Creating a series, accessing indexes, values and values by their index 
xs = pd.Series(np.arange(10)*0.5, index=tuple(letters[:10]))
print ("xs:", xs,'\n')
print ("xs indexes:",xs.index,'\n')
# Values of the Series are actually a numpy array
print ("xs values:", xs.values, type(xs.values),'\n')
print (xs['f'], xs.f, xs.h, '\n')
print (xs[['d', 'f', 'h']], '\n')
print (type(xs[['d', 'f', 'h']]), '\n')
# Out:
# xs: a    0.0
# b    0.5
# c    1.0
# d    1.5
# e    2.0
# f    2.5
# g    3.0
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# xs indexes: Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')
#
# xs values: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5] <class 'numpy.ndarray'>
#
# 2.5 2.5 3.5
#
# d    1.5
# f    2.5
# h    3.5
# dtype: float64
#
# <class 'pandas.core.series.Series'>

# %%
# Extracting elements and operations: same as numpy array
print (xs[:3],'\n')
print (xs[7:], '\n')
print (xs[::3], '\n')
print (xs[xs>3], '\n')
print (np.exp(xs), '\n')
print (np.mean(xs), np.std(xs), '\n')
# Out:
# a    0.0
# b    0.5
# c    1.0
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a    0.0
# d    1.5
# g    3.0
# j    4.5
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a     1.000000
# b     1.648721
# c     2.718282
# d     4.481689
# e     7.389056
# f    12.182494
# g    20.085537
# h    33.115452
# i    54.598150
# j    90.017131
# dtype: float64
#
# 2.25 1.4361406616345072

# %%
# Series can be created from python dictionary too.
# Not that the elements can be whatever!
d = {'b' : 1, 'a' : 'cat', 'c' : [2,3]}
pd.Series(d)
# Out:
# b         1
# a       cat
# c    [2, 3]
# dtype: object

# %% [markdown]
# A key difference between Series and ndarray is that operations between Series automatically align the data based on label. Thus, you can write computations without considering whether the Series involved have the same labels.

# %%
s = pd.Series(np.random.randn(5), index=tuple(letters[:5]))
print(s)
s = s[1:] + s[:-1]
print(s)
# Out:
# a    0.985771
# b   -0.860761
# c    0.017483
# d   -0.412599
# e   -0.606672
# dtype: float64
# a         NaN
# b   -1.721521
# c    0.034966
# d   -0.825199
# e         NaN
# dtype: float64

# %% [markdown]
# ### Time series
#
# Time series are very often used to profile the behaviour of a quantity as a function of time. Pandas has a special index for that, `DatetimeIndex`, that can be created e.g. with the function `pd.data_range()`

# %%
# to define a date, the datetime module is very useful
import datetime as dt
date = dt.date.today()
print(date)

date = dt.datetime(2022,11,30,10,45,10,15)
print (date)

# otherwise, several notations are interpreted too
date = 'Nov 30 2022'
# or alternatively
date = '30/11/2022 10:45:00'
print (date)

days = pd.date_range(date, periods=7, freq='D')
print (days)

seconds = pd.date_range(date, periods=3600, freq='s')
print (seconds)
# Out:
# 2022-11-30
# 2022-11-30 10:45:10.000015
# 30/11/2022 10:45:00
# DatetimeIndex(['2022-11-30 10:45:00', '2022-12-01 10:45:00',
#                '2022-12-02 10:45:00', '2022-12-03 10:45:00',
#                '2022-12-04 10:45:00', '2022-12-05 10:45:00',
#                '2022-12-06 10:45:00'],
#               dtype='datetime64[ns]', freq='D')
# DatetimeIndex(['2022-11-30 10:45:00', '2022-11-30 10:45:01',
#                '2022-11-30 10:45:02', '2022-11-30 10:45:03',
#                '2022-11-30 10:45:04', '2022-11-30 10:45:05',
#                '2022-11-30 10:45:06', '2022-11-30 10:45:07',
#                '2022-11-30 10:45:08', '2022-11-30 10:45:09',
#                ...
#                '2022-11-30 11:44:50', '2022-11-30 11:44:51',
#                '2022-11-30 11:44:52', '2022-11-30 11:44:53',
#                '2022-11-30 11:44:54', '2022-11-30 11:44:55',
#                '2022-11-30 11:44:56', '2022-11-30 11:44:57',
#                '2022-11-30 11:44:58', '2022-11-30 11:44:59'],
#               dtype='datetime64[ns]', length=3600, freq='S')

# %% [markdown]
# To learn more about the frequency strings, please see this [link](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases)
#
#
# Timestamped data is the most basic type of time series data that associates values with points in time. For pandas objects it means using the points in time.
#
# functions like `pd.to_datetime` can be used, for instance, when reading information as string from a dataset.
#
# Timestamp is the pandas equivalent of python’s Datetime and is interchangeable with it in most cases.

# %%
tstamp = pd.Timestamp(dt.datetime(2020, 11, 9))

# internally it counts the nanoseconds from January 1st 19
#tstamp = pd.Timestamp(dt.datetime(1970, 1, 1, 0, 0, 0, 1))
print(tstamp.value)

# when creating a timestamp the format can be explicitly passed
ts = pd.to_datetime('2010/11/12', format='%Y/%m/%d')
print (type(ts))
print (ts.value)
ts = pd.to_datetime('12-11-2010 00:00', format='%d-%m-%Y %H:%M')
print (ts)
print (ts.value)
# Out:
# 1604880000000000000
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 1289520000000000000
# 2010-11-12 00:00:00
# 1289520000000000000

# %% [markdown]
# A standard series can be created and (range of) elements can be used as indexes

# %%
tseries = pd.Series(np.random.normal(10, 1, len(days)), index=days)
# Extracting elements
print (tseries[0:4], '\n')
print (tseries['2022-11-30':'2022-12-01'], '\n') # Note - includes end time
# Out:
# 2022-11-30 10:45:00    10.251877
# 2022-12-01 10:45:00    10.835809
# 2022-12-02 10:45:00     8.578109
# 2022-12-03 10:45:00     9.769679
# Freq: D, dtype: float64
#
# 2022-11-30 10:45:00    10.251877
# 2022-12-01 10:45:00    10.835809
# Freq: D, dtype: float64

# %% [markdown]
# `pd.to_datetime` can also be used to create a `DatetimeIndex`:

# %%
pd.to_datetime([1, 2, 3, 4], unit='D', origin=pd.Timestamp('1980-02-03'))
# Out:
# DatetimeIndex(['1980-02-04', '1980-02-05', '1980-02-06', '1980-02-07'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## DataFrame
#
# A pandas DataFrame is like a simple tabular spreadsheet. For future reference (or for people already familiar with R), a pandas DataFrame is very similar to the R DataFrame.
#
# Each column in a DataFrame is a Series object.
#
# The element can be whatever, missing data are dealt with too (as NaN)

# %% [markdown]
# ### DataFrame creation
#
# A DataFrame can be created implicitly, with, e.g., a DatatimeIndex object as index:

# %%
entries=10
dates=pd.date_range('11/30/2022 10:45:00',freq='h', periods=entries)
df = pd.DataFrame(np.random.randn(entries,4), index=dates, columns=['A','B','C','D'])
df
# Out:
#                             A         B         C         D
# 2022-11-30 10:45:00 -0.424441  1.848221  0.666327  1.064513
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  0.257001
# 2022-11-30 12:45:00  0.907383 -0.841672 -0.330625  0.150700
# 2022-11-30 13:45:00  1.012084 -2.545264 -0.214500 -1.171015
# 2022-11-30 14:45:00 -0.439300  1.644534  1.146864  0.554503
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  0.327487
# 2022-11-30 16:45:00 -1.068125  0.232513 -0.813599 -0.077513
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  1.062734
# 2022-11-30 18:45:00  0.499714 -0.193889 -0.657454  0.717354
# 2022-11-30 19:45:00  1.877466  0.480138 -0.165662  0.060313

# %% [markdown]
# or by means of a dictionary:

# %%
df2 = pd.DataFrame(
    { 'A' : 1.,
      'B' : pd.Timestamp('20130102'),
      'C' : pd.Series(1,index=range(4),dtype='float32'),
      'D' : np.arange(7,11),
      'E' : pd.Categorical(["test","train","test","train"]),
    }
    )
df2

# check what happens if D and E had different lenghts
# Out:
#      A          B    C   D      E
# 0  1.0 2013-01-02  1.0   7   test
# 1  1.0 2013-01-02  1.0   8  train
# 2  1.0 2013-01-02  1.0   9   test
# 3  1.0 2013-01-02  1.0  10  train

# %% [markdown]
# ### Viewing Data

# %%
df.head(2)
# Out:
#                             A         B         C         D
# 2022-11-30 10:45:00 -0.424441  1.848221  0.666327  1.064513
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  0.257001

# %%
df.tail(4)
# Out:
#                             A         B         C         D
# 2022-11-30 16:45:00 -1.068125  0.232513 -0.813599 -0.077513
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  1.062734
# 2022-11-30 18:45:00  0.499714 -0.193889 -0.657454  0.717354
# 2022-11-30 19:45:00  1.877466  0.480138 -0.165662  0.060313

# %%
df.index
# Out:
# DatetimeIndex(['2022-11-30 10:45:00', '2022-11-30 11:45:00',
#                '2022-11-30 12:45:00', '2022-11-30 13:45:00',
#                '2022-11-30 14:45:00', '2022-11-30 15:45:00',
#                '2022-11-30 16:45:00', '2022-11-30 17:45:00',
#                '2022-11-30 18:45:00', '2022-11-30 19:45:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df
# 2022-11-30 10:45:00 -0.424441  1.848221  0.666327  1.064513
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  1.062734
# 2022-11-30 14:45:00 -0.439300  1.644534  1.146864  0.554503
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  0.327487

# %% [markdown]
# ## Selection
#
# ### Getting slices
#
# The following show how to get part of the DataFrame (i.e. not just the elements)

# %%
## standard and safe
print (df['A'],'\n')

## equivalent but dangerous (imagine blank spaces in the name of the column..)
print (df.A)
# Out:
# 2022-11-30 10:45:00   -0.424441
# 2022-11-30 11:45:00    0.557338
# 2022-11-30 12:45:00    0.907383
# 2022-11-30 13:45:00    1.012084
# 2022-11-30 14:45:00   -0.439300
# 2022-11-30 15:45:00    0.754934
# 2022-11-30 16:45:00   -1.068125
# 2022-11-30 17:45:00   -0.093437
# 2022-11-30 18:45:00    0.499714
# 2022-11-30 19:45:00    1.877466
# Freq: H, Name: A, dtype: float64
#
# 2022-11-30 10:45:00   -0.424441
# 2022-11-30 11:45:00    0.557338
# 2022-11-30 12:45:00    0.907383
# 2022-11-30 13:45:00    1.012084
# 2022-11-30 14:45:00   -0.439300
# 2022-11-30 15:45:00    0.754934
# 2022-11-30 16:45:00   -1.068125
# 2022-11-30 17:45:00   -0.093437
# 2022-11-30 18:45:00    0.499714
# 2022-11-30 19:45:00    1.877466
# Freq: H, Name: A, dtype: float64

# %%
# selecting rows by counting
print (df[0:3])

# or by index
print (df["2022-11-30 10:45:00":"2022-11-30 12:45:00"])
# Out:
#                             A         B         C         D
# 2022-11-30 10:45:00 -0.424441  1.848221  0.666327  1.064513
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  0.257001
# 2022-11-30 12:45:00  0.907383 -0.841672 -0.330625  0.150700
#                             A         B         C         D
# 2022-11-30 10:45:00 -0.424441  1.848221  0.666327  1.064513
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  0.257001
# 2022-11-30 12:45:00  0.907383 -0.841672 -0.330625  0.150700

# %% [markdown]
# ### Selection by label

# %%
# getting a cross section (part of the DataFrame) using a label
df.loc[dates[0]]
# Out:
# A   -0.424441
# B    1.848221
# C    0.666327
# D    1.064513
# Name: 2022-11-30 10:45:00, dtype: float64

# %%
# selecting on a multi-axis by label:
df.loc[:,['A','B']]
#a=df.loc[:,['A','B']]
# Out:
#                             A         B
# 2022-11-30 10:45:00 -0.424441  1.848221
# 2022-11-30 11:45:00  0.557338 -0.056223
# 2022-11-30 12:45:00  0.907383 -0.841672
# 2022-11-30 13:45:00  1.012084 -2.545264
# 2022-11-30 14:45:00 -0.439300  1.644534
# 2022-11-30 15:45:00  0.754934  0.686613
# 2022-11-30 16:45:00 -1.068125  0.232513
# 2022-11-30 17:45:00 -0.093437  0.234290
# 2022-11-30 18:45:00  0.499714 -0.193889
# 2022-11-30 19:45:00  1.877466  0.480138

# %%
# showing label slicing, both endpoints are included:
df.loc['2022-11-30 14:45:00':'2022-11-30 16:45:00',['A','B']]
# Out:
#                             A         B
# 2022-11-30 14:45:00 -0.439300  1.644534
# 2022-11-30 15:45:00  0.754934  0.686613
# 2022-11-30 16:45:00 -1.068125  0.232513

# %%
# getting an individual element
print (df.loc[dates[1],'A'])

# equivalently
print (df.at[dates[1],'A'])
# Out:
# 0.5573375037562821
# 0.5573375037562821

# %% [markdown]
# ### Selecting by position

# %%
# select via the position of the passed integers:
print (df.iloc[3],'\n')

# notation similar to numpy/python
print (df.iloc[3:5,0:2])
# Out:
# A    1.012084
# B   -2.545264
# C   -0.214500
# D   -1.171015
# Name: 2022-11-30 13:45:00, dtype: float64
#
#                             A         B
# 2022-11-30 13:45:00  1.012084 -2.545264
# 2022-11-30 14:45:00 -0.439300  1.644534

# %%
# selecting raws 1,2 and 4 for columns 0 and 2
df.iloc[[1,2,4],[0,2]]
# Out:
#                             A         C
# 2022-11-30 11:45:00  0.557338 -0.078227
# 2022-11-30 12:45:00  0.907383 -0.330625
# 2022-11-30 14:45:00 -0.439300  1.146864

# %%
# slicing rows explicitly
print (df.iloc[1:3,:],'\n')

# slicing columns explicitly
print (df.iloc[:,1:3])
# Out:
#                             A         B         C         D
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  0.257001
# 2022-11-30 12:45:00  0.907383 -0.841672 -0.330625  0.150700
#
#                             B         C
# 2022-11-30 10:45:00  1.848221  0.666327
# 2022-11-30 11:45:00 -0.056223 -0.078227
# 2022-11-30 12:45:00 -0.841672 -0.330625
# 2022-11-30 13:45:00 -2.545264 -0.214500
# 2022-11-30 14:45:00  1.644534  1.146864
# 2022-11-30 15:45:00  0.686613  1.479073
# 2022-11-30 16:45:00  0.232513 -0.813599
# 2022-11-30 17:45:00  0.234290  0.896532
# 2022-11-30 18:45:00 -0.193889 -0.657454
# 2022-11-30 19:45:00  0.480138 -0.165662

# %%
# selecting an individual element by position
df.iloc[1,1]
df.iat[1,1]
# Out:
# -0.0562230471410141

# %% [markdown]
# ### Boolean index
#
# Very powerful way of filtering out data with certain features. Notation is very similar to numpy arrays.

# %%
# Filter by a boolean condition on the values of a single column
df[df['B'] > 0]
# Out:
#                             A         B         C         D
# 2022-11-30 10:45:00 -0.424441  1.848221  0.666327  1.064513
# 2022-11-30 14:45:00 -0.439300  1.644534  1.146864  0.554503
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  0.327487
# 2022-11-30 16:45:00 -1.068125  0.232513 -0.813599 -0.077513
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  1.062734
# 2022-11-30 19:45:00  1.877466  0.480138 -0.165662  0.060313

# %%
# Selecting on the basis of boolean conditions applied to the whole DataFrame
df[df>0]

# a DataFrame with the same shape is returned, with NaN's where condition is not met
# Out:
#                             A         B         C         D
# 2022-11-30 10:45:00       NaN  1.848221  0.666327  1.064513
# 2022-11-30 11:45:00  0.557338       NaN       NaN  0.257001
# 2022-11-30 12:45:00  0.907383       NaN       NaN  0.150700
# 2022-11-30 13:45:00  1.012084       NaN       NaN       NaN
# 2022-11-30 14:45:00       NaN  1.644534  1.146864  0.554503
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  0.327487
# 2022-11-30 16:45:00       NaN  0.232513       NaN       NaN
# 2022-11-30 17:45:00       NaN  0.234290  0.896532  1.062734
# 2022-11-30 18:45:00  0.499714       NaN       NaN  0.717354
# 2022-11-30 19:45:00  1.877466  0.480138       NaN  0.060313

# %% [markdown]
# ### Setting
#
# Combination of selection and setting of values

# %%
# setting values by label (same as by position)
df.at[dates[0],'A'] = 0

# setting and assigning a numpy array
df.loc[:,'D'] = np.array([5] * len(df))

# defining a brend new column
df['E'] = np.arange(len(df))*0.5

# defining a brend new column by means of a pd.Series: indexes must be the same!
df['E prime'] = pd.Series(np.arange(len(df))*2, index=df.index)

# %%
def dcos(theta):
    theta = theta*(np.pi/180)
    return np.cos(theta)
 
df['cosine'] = pd.Series(df["E"].apply(dcos), index=df.index)
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2022-11-30 10:45:00  0.000000  1.848221  0.666327  5  0.0        0  1.000000
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  5  0.5        2  0.999962
# 2022-11-30 12:45:00  0.907383 -0.841672 -0.330625  5  1.0        4  0.999848
# 2022-11-30 13:45:00  1.012084 -2.545264 -0.214500  5  1.5        6  0.999657
# 2022-11-30 14:45:00 -0.439300  1.644534  1.146864  5  2.0        8  0.999391
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  5  2.5       10  0.999048
# 2022-11-30 16:45:00 -1.068125  0.232513 -0.813599  5  3.0       12  0.998630
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  5  3.5       14  0.998135
# 2022-11-30 18:45:00  0.499714 -0.193889 -0.657454  5  4.0       16  0.997564
# 2022-11-30 19:45:00  1.877466  0.480138 -0.165662  5  4.5       18  0.996917

# %%
# another example of global setting
df2=df.copy()

df2[df2>0] = -df2
df2
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2022-11-30 10:45:00  0.000000 -1.848221 -0.666327 -5  0.0        0 -1.000000
# 2022-11-30 11:45:00 -0.557338 -0.056223 -0.078227 -5 -0.5       -2 -0.999962
# 2022-11-30 12:45:00 -0.907383 -0.841672 -0.330625 -5 -1.0       -4 -0.999848
# 2022-11-30 13:45:00 -1.012084 -2.545264 -0.214500 -5 -1.5       -6 -0.999657
# 2022-11-30 14:45:00 -0.439300 -1.644534 -1.146864 -5 -2.0       -8 -0.999391
# 2022-11-30 15:45:00 -0.754934 -0.686613 -1.479073 -5 -2.5      -10 -0.999048
# 2022-11-30 16:45:00 -1.068125 -0.232513 -0.813599 -5 -3.0      -12 -0.998630
# 2022-11-30 17:45:00 -0.093437 -0.234290 -0.896532 -5 -3.5      -14 -0.998135
# 2022-11-30 18:45:00 -0.499714 -0.193889 -0.657454 -5 -4.0      -16 -0.997564
# 2022-11-30 19:45:00 -1.877466 -0.480138 -0.165662 -5 -4.5      -18 -0.996917

# %%
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2022-11-30 10:45:00  0.000000  1.848221  0.666327  5  0.0        0  1.000000
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  5  0.5        2  0.999962
# 2022-11-30 12:45:00  0.907383 -0.841672 -0.330625  5  1.0        4  0.999848
# 2022-11-30 13:45:00  1.012084 -2.545264 -0.214500  5  1.5        6  0.999657
# 2022-11-30 14:45:00 -0.439300  1.644534  1.146864  5  2.0        8  0.999391
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  5  2.5       10  0.999048
# 2022-11-30 16:45:00 -1.068125  0.232513 -0.813599  5  3.0       12  0.998630
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  5  3.5       14  0.998135
# 2022-11-30 18:45:00  0.499714 -0.193889 -0.657454  5  4.0       16  0.997564
# 2022-11-30 19:45:00  1.877466  0.480138 -0.165662  5  4.5       18  0.996917

# %% [markdown]
# ### Dropping
#
# N.B.: dropping doesn't act permanently on the DataFrame, i.e. to get that do :
# ```python
# df = df.drop(....)
# ```

# %%
# Dropping by column
df.drop(['E prime'], axis=1)

#which is equivalent to
new_df=df.drop(columns=['E prime'])
new_df
# Out:
#                             A         B         C  D    E    cosine
# 2022-11-30 10:45:00  0.000000  1.848221  0.666327  5  0.0  1.000000
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  5  0.5  0.999962
# 2022-11-30 12:45:00  0.907383 -0.841672 -0.330625  5  1.0  0.999848
# 2022-11-30 13:45:00  1.012084 -2.545264 -0.214500  5  1.5  0.999657
# 2022-11-30 14:45:00 -0.439300  1.644534  1.146864  5  2.0  0.999391
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  5  2.5  0.999048
# 2022-11-30 16:45:00 -1.068125  0.232513 -0.813599  5  3.0  0.998630
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  5  3.5  0.998135
# 2022-11-30 18:45:00  0.499714 -0.193889 -0.657454  5  4.0  0.997564
# 2022-11-30 19:45:00  1.877466  0.480138 -0.165662  5  4.5  0.996917

# %%
# Dropping by raws
# safe and always working
df.drop(df.index[[1,2,3,4]])
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2022-11-30 10:45:00  0.000000  1.848221  0.666327  5  0.0        0  1.000000
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  5  2.5       10  0.999048
# 2022-11-30 16:45:00 -1.068125  0.232513 -0.813599  5  3.0       12  0.998630
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  5  3.5       14  0.998135
# 2022-11-30 18:45:00  0.499714 -0.193889 -0.657454  5  4.0       16  0.997564
# 2022-11-30 19:45:00  1.877466  0.480138 -0.165662  5  4.5       18  0.996917

# %%
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2022-11-30 10:45:00  0.000000  1.848221  0.666327  5  0.0        0  1.000000
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  5  0.5        2  0.999962
# 2022-11-30 12:45:00  0.907383 -0.841672 -0.330625  5  1.0        4  0.999848
# 2022-11-30 13:45:00  1.012084 -2.545264 -0.214500  5  1.5        6  0.999657
# 2022-11-30 14:45:00 -0.439300  1.644534  1.146864  5  2.0        8  0.999391
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  5  2.5       10  0.999048
# 2022-11-30 16:45:00 -1.068125  0.232513 -0.813599  5  3.0       12  0.998630
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  5  3.5       14  0.998135
# 2022-11-30 18:45:00  0.499714 -0.193889 -0.657454  5  4.0       16  0.997564
# 2022-11-30 19:45:00  1.877466  0.480138 -0.165662  5  4.5       18  0.996917

# %%
# something like df.drop('index_name') 
# would work but the type of index must be specificed, 
# in particular with DatetimeIndex
df.drop(pd.to_datetime("2022-11-30 18:45:00"))
# Out:
#                             A         B         C  D    E  E prime    cosine
# 
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2022-11-30 10:45:00  0.000000  1.848221  0.666327  5  0.0        0  1.000000
# 2022-11-30 11:45:00  0.557338 -0.056223 -0.078227  5  0.5        2  0.999962
# 2022-11-30 12:45:00  0.907383 -0.841672 -0.330625  5  1.0        4  0.999848
# 2022-11-30 13:45:00  1.012084 -2.545264 -0.214500  5  1.5        6  0.999657
# 2022-11-30 14:45:00 -0.439300  1.644534  1.146864  5  2.0        8  0.999391
# 2022-11-30 15:45:00  0.754934  0.686613  1.479073  5  2.5       10  0.999048
# 2022-11-30 16:45:00 -1.068125  0.232513 -0.813599  5  3.0       12  0.998630
# 2022-11-30 17:45:00 -0.093437  0.234290  0.896532  5  3.5       14  0.998135
# 2022-11-30 18:45:00  0.499714 -0.193889 -0.657454  5  4.0       16  0.997564
# 2022-11-30 19:45:00  1.877466  0.480138 -0.165662  5  4.5       18  0.996917

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A           2.945591
# B           4.393486
# C           2.292672
# D           0.000000
# E           4.500000
# E prime    18.000000
# cosine      0.003083
# dtype: float64

# %%
# syntax is as usual similar to that of numpy arrays
df['A']+df['B']
# Out:
# 2022-11-30 10:45:00    1.848221
# 2022-11-30 11:45:00    0.501114
# 2022-11-30 12:45:00    0.065711
# 2022-11-30 13:45:00   -1.533180
# 2022-11-30 14:45:00    1.205234
# 2022-11-30 15:45:00    1.441547
# 2022-11-30 16:45:00   -0.835612
# 2022-11-30 17:45:00    0.140853
# 2022-11-30 18:45:00    0.305825
# 2022-11-30 19:45:00    2.357604
# Freq: H, dtype: float64

# %% [markdown]
# Let's play it hard and load (in memory) a (relatively) large dataset

# %%
# WARNING! link in past notebook was wrong!, (if needed) get the right file from:
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

file_name="~/data/data_000637.txt"
data=pd.read_csv(file_name)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11718/2785434663.py in <module>
#       3
#       4 file_name="~/data/data_000637.txt"
# ----> 5 data=pd.read_csv(file_name)
#       6 data
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/marco/data/data_000637.txt'

# %% [markdown]
# Let's now do some operations among (elements of) columns

# %%
# the one-liner killing it all
data['timens']=data['TDC_MEAS']*25/30+data['BX_COUNTER']*25

# %%
data['timens']

# %%
# the old slooow way
def conversion(data):
    result=[]
    for i in range(len(data)): 
        result.append(data.loc[data.index[i],'TDC_MEAS']*25/30.+data.loc[data.index[i],'BX_COUNTER']*25)
    return result

data['timens']=conversion(data)

# %% [markdown]
# ## Merge
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# ### Concat
#
# concatenation (adding rows) is straightforward

# %%
rdf = pd.DataFrame(np.random.randn(10, 4))
rdf
# Out:
#           0         1         2         3
# 0  1.281648  0.179725  0.366167 -0.212754
# 1 -0.548715  2.784268  1.045268  0.257969
# 2  1.512887  1.063701 -0.252958 -0.361956
# 3 -0.305518 -0.844411 -0.982307 -1.241076
# 4  1.254588 -0.712879  0.277412 -1.254726
# 5  0.351807 -2.299675  0.460758  0.481643
# 6 -0.346869 -0.358859 -0.705079 -0.772823
# 7  0.330502 -0.542823  0.103864 -0.041023
# 8  0.367531 -0.566664 -1.743274  0.131527
# 9  0.432785 -0.532302  0.244892 -0.603503

# %%
# divide it into pieaces raw-wise
pieces = [rdf[:3], rdf[3:7], rdf[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  1.281648  0.179725  0.366167 -0.212754
#  1 -0.548715  2.784268  1.045268  0.257969
#  2  1.512887  1.063701 -0.252958 -0.361956,
#            0         1         2         3
#  3 -0.305518 -0.844411 -0.982307 -1.241076
#  4  1.254588 -0.712879  0.277412 -1.254726
#  5  0.351807 -2.299675  0.460758  0.481643
#  6 -0.346869 -0.358859 -0.705079 -0.772823,
#            0         1         2         3
#  7  0.330502 -0.542823  0.103864 -0.041023
#  8  0.367531 -0.566664 -1.743274  0.131527
#  9  0.432785 -0.532302  0.244892 -0.603503]

# %%
# put it back together
#pd.concat(pieces)

# indexes can be ignored
pd.concat(pieces, ignore_index=True)

# in case of dimension mismatch, Nan are added where needed
# Out:
#           0         1         2         3
# 0  1.281648  0.179725  0.366167 -0.212754
# 1 -0.548715  2.784268  1.045268  0.257969
# 2  1.512887  1.063701 -0.252958 -0.361956
# 3 -0.305518 -0.844411 -0.982307 -1.241076
# 4  1.254588 -0.712879  0.277412 -1.254726
# 5  0.351807 -2.299675  0.460758  0.481643
# 6 -0.346869 -0.358859 -0.705079 -0.772823
# 7  0.330502 -0.542823  0.103864 -0.041023
# 8  0.367531 -0.566664 -1.743274  0.131527
# 9  0.432785 -0.532302  0.244892 -0.603503

# %%
# appending a single row (as a Series)
s = rdf.iloc[3]
rdf.append(s, ignore_index=True)
rdf
# Out:
# /tmp/ipykernel_11718/3203204840.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   rdf.append(s, ignore_index=True)
#           0         1         2         3
# 0  1.281648  0.179725  0.366167 -0.212754
# 1 -0.548715  2.784268  1.045268  0.257969
# 2  1.512887  1.063701 -0.252958 -0.361956
# 3 -0.305518 -0.844411 -0.982307 -1.241076
# 4  1.254588 -0.712879  0.277412 -1.254726
# 5  0.351807 -2.299675  0.460758  0.481643
# 6 -0.346869 -0.358859 -0.705079 -0.772823
# 7  0.330502 -0.542823  0.103864 -0.041023
# 8  0.367531 -0.566664 -1.743274  0.131527
# 9  0.432785 -0.532302  0.244892 -0.603503

# %% [markdown]
# ### Merge/Join
#
# SQL like operations on table can be performed on DataFrames. This is all rather sophisticated, refer to the [doc](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging) for more info/examples

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
print(left)
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
print(right)
pd.merge(left,right,on="key")
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2
#    key  rval
# 0  foo     4
# 1  bar     5
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps:
#
# * Splitting the data into groups based on some criteria
# * Applying a function to each group independently
# * Combining the results into a data structure

# %%
gdf = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three',
                           'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})
gdf
# Out:
#      A      B         C         D
# 0  foo    one  0.612223  2.802660
# 1  bar    one  0.919128 -0.563313
# 2  foo    two  0.037216 -0.507549
# 3  bar  three  1.312396  0.677864
# 4  foo    two -0.600651 -1.399480
# 5  bar    two  0.590372  0.922242
# 6  foo    one  1.218742  1.326829
# 7  foo  three  0.057748 -1.165176

# %%
# Grouping and then applying the sum() 
# function to the resulting groups (effective only where number are there).
gdf.groupby('A').sum()
# Out:
#             C         D
# A
# bar  2.821895  1.036793
# foo  1.325278  1.057283

# %% [markdown]
# ## Multi-indexing
#
#
# Hierarchical / Multi-level indexing allows sophisticated data analysis on higher dimensional data. In essence, it enables you to store and manipulate data with an arbitrary number of dimensions in lower dimensional data structures like Series (1d) and DataFrame (2d).

# %%
tuples = list(zip(['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
          ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']))
multi_index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
print (multi_index,'\n')

s = pd.Series(np.random.randn(8), index=multi_index)
print (s)
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])
#
# first  second
# bar    one       0.324217
#        two       1.205309
# baz    one       0.137622
#        two       1.164618
# foo    one      -0.695946
#        two       0.397375
# qux    one      -1.085172
#        two      -0.126321
# dtype: float64

# %%
# it enables further features of the groupby method,
# e.g. when group-by by multiple columns
gdf.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.919128 -0.563313
#     three  1.312396  0.677864
#     two    0.590372  0.922242
# foo one    1.830965  4.129489
#     three  0.057748 -1.165176
#     two   -0.563435 -1.907029

# %%
# stack() method “compresses” a level in the DataFrame’s columns
gdf.groupby(['A','B']).sum().stack()
# Out:
# A    B
# bar  one    C    0.919128
#             D   -0.563313
#      three  C    1.312396
#             D    0.677864
#      two    C    0.590372
#             D    0.922242
# foo  one    C    1.830965
#             D    4.129489
#      three  C    0.057748
#             D   -1.165176
#      two    C   -0.563435
#             D   -1.907029
# dtype: float64

# %% [markdown]
# ## Plotting
#
# Just a preview, more on the next lab class!

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

pdf=pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
pdf = pdf.cumsum()
plt.figure(); pdf.plot(); plt.legend(loc='best')
